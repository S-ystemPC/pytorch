# %% [markdown]
# # 1. Created virtual environment and downloaded cuda, also downloaded PyTorch with cuda support in the virtual environment.

# %% [markdown]
# # 2. Tensors

# %% [markdown]
# # 2.1 Empty Tensors

# %%
import torch

x1 = torch.empty(1)
print(x1)
# Out:
# tensor([0.])

# %%
x2 = torch.empty(2, 2)
print(x2)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
x3 = torch.empty(2, 2, 3)
print(x3)
# Out:
# tensor([[[5.4947e+08, 1.1098e-42, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00]]])

# %%
# Corrected the virtual environment again today which takes all the time

# %%
torch.cuda.is_available()
# Out:
# False
